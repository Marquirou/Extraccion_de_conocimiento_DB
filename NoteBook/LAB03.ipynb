# %% [markdown]
# <a href="https://colab.research.google.com/github/Marquirou/Extraccion_de_conocimiento_DB/blob/main/LAB03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/telecom_churn.csv"

# %%
df=pd.read_csv(url)

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=["object","bool"])
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3333
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2850

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
df.sample()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 529    DC             100        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 529                      0               68.5              110
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 529             11.65              337.1              115             28.65
#
#      Total night minutes  Total night calls  Total night charge  \
# 529                205.2                 99                9.23
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 529                12.1                 9               3.27
#
#      Customer service calls  Churn
# 529                       0  False

# %%
df.sample(3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 891     AZ              87        510                 No              No
# 2128    MT              73        408                 No             Yes
# 2661    IA             197        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 891                       0              110.9               91
# 2128                     26              131.2               98
# 2661                      0              233.9               96
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 891              18.85              158.5              115             13.47
# 2128             22.30              106.5               97              9.05
# 2661             39.76              218.9              111             18.61
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
df["State"]
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df.loc[4]
# Out:
# State                        OK
# Account length               75
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         166.7
# Total day calls             113
# Total day charge          28.34
# Total eve minutes         148.3
# Total eve calls             122
# Total eve charge          12.61
# Total night minutes       186.9
# Total night calls           121
# Total night charge         8.41
# Total intl minutes         10.1
# Total intl calls              3
# Total intl charge          2.73
# Customer service calls        3
# Churn                     False
# Name: 4, dtype: object

# %%
df.loc[[20,30]]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 20    FL             147        415                 No              No
# 30    IL             142        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 20                      0              155.1              117
# 30                      0               84.8               95
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 20             26.37              239.7               93             20.37
# 30             14.42              136.7               63             11.62
#
#     Total night minutes  Total night calls  Total night charge  \
# 20                208.8                133                9.40
# 30                250.5                148               11.27
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 20                10.6                 4               2.86
# ...

# %%
df["Churn"] = df["Churn"].asType("int64")

# %%
df["Churn"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool
