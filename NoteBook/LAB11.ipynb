# %% [markdown]
# ## LAB11: Procesamiento de datos para Machine Learning
#
# Objetivo: Aplicar las principales tecnicas de procesamiento de datos para preparar un DataSet antes de entrar un modelo de ML
#
# Problema: Se desea construir un modelo capaz de predecir si un pasajero sobrevivio o no al hundimiento del titanic

# %%
#Importar librerias 
import pandas as pd 
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kagglehub

# %%
# !pip install kagglehub

# %%
path = kagglehub.dataset_download("yasserh/titanic-dataset")

# %%
print("Ruta del dataset:", path)
# Out:
# Ruta del dataset: /home/marko/.cache/kagglehub/datasets/yasserh/titanic-dataset/versions/1

# %%
dfTitanic = pd.read_csv(path + "/Titanic-Dataset.csv")

# %%
dfTitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dfTitanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Parte 1. Comprensión del problema
# Determinar si sobreviven al hundimiento del titanic, con base en la información obtenida.
#
# Survived
#
# 0 - No sobrevivio
#
# 1 - Sobrevivio

# %%
dfTitanic["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#Graficamos 
dfTitanic["Survived"].value_counts().plot(
    kind="bar"
)
plt.title("Distribución de supervivencia")
plt.show()

# %% [markdown]
# ## Parte 2. Exploración Inicial

# %%
dfTitanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Hipotesis Inicial 
dfTitanic.groupby(
    "Sex"
)["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
dfTitanic.groupby(
    "Pclass"
)["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
dfTitanic.groupby(
    "Fare"
)["Survived"].mean()
# Out:
# Fare
# 0.0000      0.066667
# 4.0125      0.000000
# 5.0000      0.000000
# 6.2375      0.000000
# 6.4375      0.000000
#               ...
# 227.5250    0.750000
# 247.5208    0.500000
# 262.3750    1.000000
# 263.0000    0.500000
# 512.3292    1.000000
# Name: Survived, Length: 248, dtype: float64

# %% [markdown]
# ## Parte 3. Correlación e Hipótesis
#
# Creamos una matriz de correlación para identificar la relación lineal entre las variables. NO identifica la importancia de variables en el modelo

# %%
variables_numericas = [
    "Survived",
    "Pclass",
    "Age",
    "SibSp",
    "Parch",
    "Fare"
]

# %%
corr = dfTitanic[variables_numericas].corr()

# %%
corr
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# ## Parte 4. Selección de variables Predictoras y Variable objetivo
#
# X - Variables que utilizara el modelo
#
# Y - Variables que queremos predecir

# %%
columnas = [
    "Pclass",
    "Sex",
    "Age",
    "SibSp",
    "Parch",
    "Fare",
    "Embarked"
]

# %%
#Definimos x y 
x = dfTitanic[columnas]
y = dfTitanic["Survived"]

# %%
print(x.columns.tolist())
# Out:
# ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
print(y.name)
# Out:
# Survived

# %% [markdown]
# ## Parte 5. Tratamiento de los valores
# Para simplificar el proceso, realizaremos la imputación de los datos antes de la separación TRAIN/TEST

# %%
#Revisamos las variables predictoras 
x.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
x["Age"] = x["Age"].fillna(
    x["Age"].median()
)
# Out:
# /tmp/ipykernel_12146/1295983609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Age"] = x["Age"].fillna(

# %%
x["Embarked"] = x["Embarked"].fillna(
    x["Embarked"].mode() [0]
)
# Out:
# /tmp/ipykernel_12146/127214414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Embarked"] = x["Embarked"].fillna(

# %%
x.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
x.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ## Parte 6. Escalado de datos
#
# Los algoritmos no entienden texto. Se deben convertir las variables categoricas en variables númericas.

# %%
x = pd.get_dummies(
    x, 
    columns=["Sex", "Embarked"],
    drop_first=True
)

# %%
x.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S
# 0       3  22.0      1      0   7.2500      True       False        True
# 1       1  38.0      1      0  71.2833     False       False       False
# 2       3  26.0      0      0   7.9250     False       False        True
# 3       1  35.0      1      0  53.1000     False       False        True
# 4       3  35.0      0      0   8.0500      True       False        True

# %% [markdown]
# ## Parte 7. Particionamos los datos
# No debemos entrenar y evaluar utilizando los mismos datos
#
# La recomendación es:
#
# Entrenamiento: 80%
#
# Pruebas: 20%

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size = 0.20,
    random_state = 42
)

# %%
print ( "Entrenamiento: ", x_train.shape)
# Out:
# Entrenamiento:  (712, 8)

# %%
print ( "Prueba: ", y_test.shape)
# Out:
# Prueba:  (179,)

# %% [markdown]
# ## Parte 8. Escalado de las variables
#
# Las variables numericas tienen valores distintos. El escalado evita que una variables domine más que otra

# %%
columnas_numericas = [
    "Age",
    "Fare",
    "SibSp",
    "Parch"
]

# %%
x_train[columnas_numericas].describe()
# Out:
#               Age        Fare       SibSp       Parch
# count  712.000000  712.000000  712.000000  712.000000
# mean    29.204129   32.586276    0.553371    0.379213
# std     13.007971   51.969529    1.176404    0.791669
# min      0.420000    0.000000    0.000000    0.000000
# 25%     22.000000    7.925000    0.000000    0.000000
# 50%     28.000000   14.454200    0.000000    0.000000
# 75%     35.000000   30.500000    1.000000    0.000000
# max     80.000000  512.329200    8.000000    6.000000

# %%
scaler = StandardScaler()
x_train[columnas_numericas] = scaler.fit_transform(
    x_train[columnas_numericas]
)
x_test[columnas_numericas] = scaler.transform(
    x_test[columnas_numericas]
)

# %%
x_train[columnas_numericas].describe()
# Out:
#                 Age          Fare         SibSp         Parch
# count  7.120000e+02  7.120000e+02  7.120000e+02  7.120000e+02
# mean   1.746418e-17  5.363999e-17  1.746418e-17  2.245395e-17
# std    1.000703e+00  1.000703e+00  1.000703e+00  1.000703e+00
# min   -2.214363e+00 -6.274674e-01 -4.707224e-01 -4.793416e-01
# 25%   -5.542135e-01 -4.748670e-01 -4.707224e-01 -4.793416e-01
# 50%   -9.263364e-02 -3.491435e-01 -4.707224e-01 -4.793416e-01
# 75%    4.458762e-01 -4.017244e-02  3.799232e-01 -4.793416e-01
# max    3.907725e+00  9.237724e+00  6.334442e+00  7.104908e+00

# %% [markdown]
# ## Parte 9. Entrenamiento de los datos
# Usaremos una árbol de decisión para clasificar registros

# %%
modelo = DecisionTreeClassifier (
    max_depth = 4,
    random_state=42
)

# %%
modelo.fit(
    x_train,
    y_train
)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %% [markdown]
# ## Parte 10. Evaluamos el modelo
# Realizamos predicciones para evaluar el modelo

# %%
predicciones = modelo.predict(
    x_test
)

# %%
pd.DataFrame({
    "Real ": y_test,
    "Prediccion ": predicciones
}).head(15)
# Out:
#      Real   Prediccion
# 709      1            0
# 439      0            0
# 840      0            0
# 720      1            1
# 39       1            1
# 290      1            1
# 300      1            1
# 333      0            0
# 208      1            1
# 136      1            1
# 137      0            0
# 696      0            0
# 485      0            0
# 244      0            0
# 344      0            0

# %% [markdown]
# ## Parte 11. Evaluación del modelo
# El accuracy determina el porcentaje de predicciones correctas realizadas por el modelo

# %%
accuracy = accuracy_score(
    y_test,
    predicciones
)

# %%
print(f"Accuracy {accuracy:.4f}")
# Out:
# Accuracy 0.7989

# %% [markdown]
# | Accuracy | Interpretación |
# | --- | --- |
# | 50% | Adivina |
# | 60% - 70% | Aceptable / Básico |
# | 70% - 80% | Bueno |
# | 80% - 90% | Muy bueno |
# | > 90% | Excelente |

# %% [markdown]
# ## Parte 12. Importancia de las variables
# Analizar las variables más relevantes para el algoritmo, al realizar las predicciones

# %%
importancias = pd.DataFrame({
    "Variable" : x_train.columns,
    "Importancia" : modelo.feature_importances_ #Que variable es importante para el modelo
})

# %%
importancias.sort_values(
    by="Importancia",
    ascending=False
)
# Out:
#      Variable  Importancia
# 5    Sex_male     0.579608
# 0      Pclass     0.200498
# 4        Fare     0.081064
# 1         Age     0.078872
# 2       SibSp     0.046059
# 7  Embarked_S     0.013900
# 3       Parch     0.000000
# 6  Embarked_Q     0.000000
